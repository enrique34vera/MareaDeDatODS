# %%
import pandas as pd
import plotly.express as px
import plotly.graph_objects as go

# %%
poblacion_Veracruz = pd.read_csv('../datos/conjunto_de_datos_iter_30CSV20.csv', usecols=[3,5,9])

# %%
poblacion_Veracruz
# Out:
#                                                  NOM_MUN  \
# 0      Total de la entidad Veracruz de Ignacio de la ...
# 1      Total de la entidad Veracruz de Ignacio de la ...
# 2      Total de la entidad Veracruz de Ignacio de la ...
# 3                                                Acajete
# 4                                                Acajete
# ...                                                  ...
# 20396                                 Santiago Sochiapan
# 20397                                 Santiago Sochiapan
# 20398                                 Santiago Sochiapan
# 20399                                 Santiago Sochiapan
# 20400                                 Santiago Sochiapan
#
#                             NOM_LOC   POBTOT
# 0               Total de la Entidad  8062579
# 1       Localidades de una vivienda    21944
# 2      Localidades de dos viviendas    13479
# 3               Total del Municipio     9701
# 4                           Acajete     1810
# ...                             ...      ...
# 20396                     Loma Alta       23
# 20397                 Corpus Cristy        4
# 20398                   El Nazareno      136
# 20399   Localidades de una vivienda       80
# 20400  Localidades de dos viviendas       79
#
# [20401 rows x 3 columns]

# %%
poblacionXmunicipio = poblacion_Veracruz.loc[poblacion_Veracruz['NOM_LOC']=='Total del Municipio']
poblacionXmunicipio
# Out:
#                       NOM_MUN              NOM_LOC  POBTOT
# 3                     Acajete  Total del Municipio    9701
# 49                    Acatlán  Total del Municipio    3441
# 56                   Acayucan  Total del Municipio   80815
# 307                   Actopan  Total del Municipio   41742
# 504                     Acula  Total del Municipio    5253
# ...                       ...                  ...     ...
# 19951      Carlos A. Carrillo  Total del Municipio   23376
# 20011  Tatahuicapan de Juárez  Total del Municipio   15044
# 20070                Uxpanapa  Total del Municipio   30891
# 20226              San Rafael  Total del Municipio   30351
# 20313      Santiago Sochiapan  Total del Municipio   13062
#
# [212 rows x 3 columns]

# %%
municipios_mas_poblados=poblacionXmunicipio.sort_values(by='POBTOT', ascending=False).iloc[0:10]
municipios_mas_poblados
# Out:
#                     NOM_MUN              NOM_LOC  POBTOT
# 18876              Veracruz  Total del Municipio  607209
# 7165                 Xalapa  Total del Municipio  488531
# 2790          Coatzacoalcos  Total del Municipio  310698
# 3092                Córdoba  Total del Municipio  204721
# 12284  Poza Rica de Hidalgo  Total del Municipio  189457
# 12635     San Andrés Tuxtla  Total del Municipio  162428
# 11211              Papantla  Total del Municipio  159910
# 18353                Tuxpan  Total del Municipio  154600
# 8782             Minatitlán  Total del Municipio  144776
# 2080           Boca del Río  Total del Municipio  144550

# %%
fig=px.bar(municipios_mas_poblados, x='NOM_MUN', y='POBTOT', color_discrete_sequence=['indianred'], text_auto=True)
fig.update_layout(xaxis_title=" ", yaxis_title="Población total", xaxis_tickangle=45)
fig.show()
