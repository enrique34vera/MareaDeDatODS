# %%
# Importación de librerías
import pandas as pd
import plotly.express as px
import plotly.graph_objects as go

# %%
# Lectura de datos
nivel_del_mar = pd.read_csv("../data/data-1_metros.csv")
temperatura = pd.read_csv("../data/data-1_gradoscelsius.csv")
humedad_rel = pd.read_csv("../data/data-1_porcentaje.csv")
velocidad_viento = pd.read_csv("../data/data-1_metrosxsegundo.csv")

# %%
velocidad_viento
# Out:
#                   Tiempo  Rapidez de viento  \
# 0    2026-03-22 20:30:00                6.3
# 1    2026-03-22 20:40:00                5.9
# 2    2026-03-22 20:50:00                5.7
# 3    2026-03-22 21:00:00                6.5
# 4    2026-03-22 21:10:00                6.1
# ..                   ...                ...
# 750  2026-03-28 01:30:00                7.5
# 751  2026-03-28 01:40:00                6.4
# 752  2026-03-28 01:50:00                6.3
# 753  2026-03-28 02:00:00                6.3
# 754  2026-03-28 02:10:00                4.7
#
#      Velocidad de viento media vectorial  Velocidad de rafaga
# 0                                    6.8                  8.2
# 1                                    6.2                  7.9
# 2                                    6.9                  8.1
# 3                                    6.5                  8.1
# 4                                    6.6                  8.4
# ..                                   ...                  ...
# 750                                  7.4                  9.0
# 751                                  6.8                  8.8
# 752                                  6.1                  8.7
# 753                                  6.1                  7.9
# 754                                  5.5                  7.1
#
# [755 rows x 4 columns]

# %%
temperatura.iloc[-1]['Temperatura atmosferica']
# Out:
# np.float64(25.4)

# %%
humedad_rel.iloc[-1]['Humedad relativa']
# Out:
# np.float64(80.0)

# %%
velocidad_viento.iloc[-1]['Velocidad de rafaga']
# Out:
# np.float64(7.1)

# %%
# Cambiar el nombre de las columnas en el dataframe 'nivel_del_mar'
nivel_del_mar.rename(columns={'Nivel del mar (radar promedio)':'Radar promedio', 'Nivel del mar (flotador)':'Flotador'},
                    inplace=True)

# %%
# Creación de una nueva columna que contiene las fechas del archivo en formato 'datetime'
nivel_del_mar['Tiempo_datetime']=pd.to_datetime(nivel_del_mar['Tiempo'], format='%Y-%m-%d %H:%M:%S')
temperatura['Tiempo_datetime']=pd.to_datetime(temperatura['Tiempo'], format='%Y-%m-%d %H:%M:%S')
humedad_rel['Tiempo_datetime']=pd.to_datetime(humedad_rel['Tiempo'], format='%Y-%m-%d %H:%M:%S')
velocidad_viento['Tiempo_datetime']=pd.to_datetime(velocidad_viento['Tiempo'], format='%Y-%m-%d %H:%M:%S')

# %%
nivel_del_mar['Radar promedio'].dropna().iloc[-1]
# Out:
# np.float64(1.674)

# %%
valor_pronostico=nivel_del_mar.iloc[3580:]
valor_medido=nivel_del_mar.iloc[0:3579]

# %%
valor_medido
# Out:
#                    Tiempo  Pronostico  Radar promedio  Flotador  \
# 0     2026-03-22 20:19:00       1.818           1.711      1.71
# 1     2026-03-22 20:20:00       1.818           1.705      1.71
# 2     2026-03-22 20:21:00       1.817           1.735      1.70
# 3     2026-03-22 20:22:00       1.817           1.698      1.70
# 4     2026-03-22 20:23:00       1.817           1.706      1.70
# ...                   ...         ...             ...       ...
# 3574  2026-03-25 07:53:00       1.273           1.172      1.17
# 3575  2026-03-25 07:54:00       1.274           1.168      1.16
# 3576  2026-03-25 07:55:00       1.275           1.169      1.16
# 3577  2026-03-25 07:56:00       1.276           1.154      1.16
# 3578  2026-03-25 07:57:00       1.277           1.145      1.15
#
#          Tiempo_datetime
# 0    2026-03-22 20:19:00
# 1    2026-03-22 20:20:00
# 2    2026-03-22 20:21:00
# 3    2026-03-22 20:22:00
# 4    2026-03-22 20:23:00
# ...                  ...
# 3574 2026-03-25 07:53:00
# 3575 2026-03-25 07:54:00
# 3576 2026-03-25 07:55:00
# 3577 2026-03-25 07:56:00
# 3578 2026-03-25 07:57:00
#
# [3579 rows x 5 columns]

# %%
#nivel_del_mar[nivel_del_mar['Radar promedio'].isna()]
#nivel_del_mar[nivel_del_mar['Radar promedio'].notna()]

# %%
# Grafica nivel del mar
fig=go.Figure()
fig.add_trace(go.Scatter(x=valor_medido['Tiempo_datetime'], y=valor_medido['Radar promedio'],
                         name='Medición', line=dict(color='green',width=2)))
fig.add_trace(go.Scatter(x=valor_pronostico['Tiempo_datetime'], y=valor_pronostico['Pronostico'],
                         name='Pronóstico', line=dict(color='blue',width=3)))
fig.update_layout(xaxis_title=" ",
                  yaxis_title="[metros]")
fig.show()

# %% [markdown]
# ## Gráfica Temperatura

# %%
fig=go.Figure()
fig.add_trace(go.Scatter(x=temperatura['Tiempo_datetime'], y=temperatura['Temperatura atmosferica'],
                         name='Medición', line=dict(color='green',width=2)))
fig.update_layout(xaxis_title=" ",
                  yaxis_title="[grados celsius]")
fig.show()

# %% [markdown]
# ## Gráfica Humedad Relativa

# %%
fig=go.Figure()
fig.add_trace(go.Scatter(x=humedad_rel['Tiempo_datetime'], y=humedad_rel['Humedad relativa'],
                         name='Medición', line=dict(color='green',width=2)))
fig.update_layout(xaxis_title=" ",
                  yaxis_title="[%]")
fig.show()

# %% [markdown]
# ## Gráfica Viento

# %%
fig=go.Figure()
fig.add_trace(go.Scatter(x=velocidad_viento['Tiempo_datetime'], y=velocidad_viento['Rapidez de viento'],
                         name='Rapidez de viento', line=dict(color='green',width=2)))
fig.add_trace(go.Scatter(x=velocidad_viento['Tiempo_datetime'], y=velocidad_viento['Velocidad de rafaga'],
                         name='Velocidad de rafaga', line=dict(color='red',width=2)))
fig.update_layout(xaxis_title=" ",
                  yaxis_title="[m/s]")
fig.show()
