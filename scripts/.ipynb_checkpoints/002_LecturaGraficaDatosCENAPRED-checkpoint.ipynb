# %%
# Importacion de librerias
import pandas as pd
import plotly.express as px
import plotly.graph_objects as go

# %%
impacto_Nacional=pd.read_excel('../datos/Basehistorica_2000_a_2024.xlsx', usecols=[0,1,2,3,4,5,6,8,9,15])
#impacto_Nacional

# %%
impacto_Veracruz=impacto_Nacional.loc[impacto_Nacional['Estado']=='Veracruz']
impacto_Veracruz_Hidrometeo=impacto_Veracruz.loc[impacto_Veracruz['Clasificación del fenómeno']=='Hidrometeorológico']

# %%
tipo_fenomeno = impacto_Veracruz_Hidrometeo['Tipo de fenómeno'].unique()
tipo_fenomeno
# Out:
# <StringArray>
# [            'Lluvias',              'Sequía', 'Bajas temperaturas ',
#     'Fuertes vientos ',          'Inundación',  'Tormenta tropical ',
#      'Ciclón tropical',  'Tormenta eléctrica',           'Granizada',
#               'Helada',    'Tormenta severa ', 'Temperatura extrema',
#          'Inundación ']
# Length: 13, dtype: str

# %%
num_tipo_fenomeno = impacto_Veracruz_Hidrometeo['Tipo de fenómeno'].value_counts().iloc[0:11]
num_tipo_fenomeno
# Out:
# Tipo de fenómeno
# Lluvias                229
# Inundación              28
# Fuertes vientos         20
# Bajas temperaturas      18
# Tormenta severa         17
# Ciclón tropical         13
# Temperatura extrema     13
# Sequía                   9
# Helada                   5
# Granizada                4
# Tormenta tropical        3
# Name: count, dtype: int64

# %%
fig=px.bar(num_tipo_fenomeno, color_discrete_sequence=['rgb(26, 118, 255)'], text_auto=True)
fig.update_layout(xaxis_title=" ", yaxis_title="Número de eventos", showlegend=False)
fig.show()

# %%
lluvias = impacto_Veracruz_Hidrometeo.loc[impacto_Veracruz_Hidrometeo['Tipo de fenómeno']=='Lluvias']
lluvias_poblacion_afect = lluvias['Población afectada '].replace('SD',0).sum()
lluvias_danos_econ = lluvias['Total de daños (millones de pesos)'].sum()

# %%
lluvias_poblacion_afect
lluvias_danos_econ
# Out:
# 21187.673003373606

# %%
poblacion_afect = {'Lluvias':lluvias_poblacion_afect}
danos_economicos = {'Lluvias':lluvias_danos_econ}

# %%
inundacion = impacto_Veracruz_Hidrometeo.loc[impacto_Veracruz_Hidrometeo['Tipo de fenómeno']=='Inundación']
inundacion_poblacion_afect = inundacion['Población afectada '].replace('SD',0).sum()
inundacion_danos_econ = inundacion['Total de daños (millones de pesos)'].sum()

# %%
inundacion_poblacion_afect
inundacion_danos_econ
# Out:
# 4446.323611711

# %%
poblacion_afect['Inundación']=inundacion_poblacion_afect
danos_economicos['Inundación']=inundacion_danos_econ

# %%
fuertes_vientos = impacto_Veracruz_Hidrometeo.loc[impacto_Veracruz_Hidrometeo['Tipo de fenómeno']=='Fuertes vientos ']
vientos_poblacion_afect = fuertes_vientos['Población afectada '].replace('SD',0).sum()
#vientos_danos_econ = fuertes_vientos['Total de daños (millones de pesos)'].sum()

# %%
vientos_poblacion_afect
#vientos_danos_econ
# Out:
# 266200

# %%
poblacion_afect['Fuertes vientos']=vientos_poblacion_afect
#danos_economicos['Fuertes vientos']=vientos_danos_econ

# %%
bajas_temperaturas = impacto_Veracruz_Hidrometeo.loc[impacto_Veracruz_Hidrometeo['Tipo de fenómeno']=='Bajas temperaturas ']
bajatemp_poblacion_afect = bajas_temperaturas['Población afectada '].replace('SD',0).sum()
#bajatemp_danos_econ = bajas_temperaturas['Total de daños (millones de pesos)'].sum()

# %%
bajatemp_poblacion_afect
#bajatemp_danos_econ
# Out:
# 89832

# %%
poblacion_afect['Bajas temperaturas']=bajatemp_poblacion_afect
#danos_economicos['Bajas temperaturas']=bajatemp_danos_econ

# %%
tormenta_severa = impacto_Veracruz_Hidrometeo.loc[impacto_Veracruz_Hidrometeo['Tipo de fenómeno']=='Tormenta severa ']
#tormenta_poblacion_afect = tormenta_severa['Población afectada '].replace('SD',0).sum()
#tormenta_danos_econ = tormenta_severa['Total de daños (millones de pesos)'].sum()

# %%
#tormenta_poblacion_afect
#tormenta_danos_econ

# %%
#poblacion_afect['Tormenta severa']=tormenta_poblacion_afect
#danos_economicos['Tormenta severa']=tormenta_danos_econ

# %%
ciclon_tropical = impacto_Veracruz_Hidrometeo.loc[impacto_Veracruz_Hidrometeo['Tipo de fenómeno']=='Ciclón tropical']
ciclon_poblacion_afect = ciclon_tropical['Población afectada '].replace('SD',0).sum()
ciclon_danos_econ = ciclon_tropical['Total de daños (millones de pesos)'].sum()

# %%
ciclon_poblacion_afect
ciclon_danos_econ
# Out:
# 48515.565813211106

# %%
poblacion_afect['Ciclón tropical']=ciclon_poblacion_afect
danos_economicos['Ciclón tropical']=ciclon_danos_econ

# %%
temp_extrema = impacto_Veracruz_Hidrometeo.loc[impacto_Veracruz_Hidrometeo['Tipo de fenómeno']=='Temperatura extrema']
#tempext_poblacion_afect = temp_extrema['Población afectada '].replace('SD',0).sum()
#tempext_danos_econ = temp_extrema['Total de daños (millones de pesos)'].sum()

# %%
#tempext_poblacion_afect
#tempext_danos_econ

# %%
#poblacion_afect['Temperatura extrema']=tempext_poblacion_afect
#danos_economicos['Temperatura extrema']=tempext_danos_econ

# %%
sequia = impacto_Veracruz_Hidrometeo.loc[impacto_Veracruz_Hidrometeo['Tipo de fenómeno']=='Sequía']
#sequia_poblacion_afect = sequia['Población afectada '].replace('SD',0).sum()
#sequia_danos_econ = sequia['Total de daños (millones de pesos)'].sum()

# %%
#sequia_poblacion_afect
#sequia_danos_econ

# %%
#poblacion_afect['Sequía']=sequia_poblacion_afect
#danos_economicos['Sequía']=sequia_danos_econ

# %%
helada = impacto_Veracruz_Hidrometeo.loc[impacto_Veracruz_Hidrometeo['Tipo de fenómeno']=='Helada']
#helada_poblacion_afect = helada['Población afectada '].replace('SD',0).sum()
#helada_danos_econ = helada['Total de daños (millones de pesos)'].sum()

# %%
#helada_poblacion_afect
#helada_danos_econ

# %%
#poblacion_afect['Helada']=helada_poblacion_afect
#danos_economicos['Helada']=helada_danos_econ

# %%
granizada = impacto_Veracruz_Hidrometeo.loc[impacto_Veracruz_Hidrometeo['Tipo de fenómeno']=='Granizada']
#granizada_poblacion_afect = granizada['Población afectada '].replace('SD',0).sum()
#granizada_danos_econ = granizada['Total de daños (millones de pesos)'].sum()

# %%
#granizada_poblacion_afect
#granizada_danos_econ

# %%
#poblacion_afect['Granizada']=granizada_poblacion_afect
#danos_economicos['Granizada']=granizada_danos_econ

# %%
tormenta_tropical = impacto_Veracruz_Hidrometeo.loc[impacto_Veracruz_Hidrometeo['Tipo de fenómeno']=='Tormenta tropical ']
#tormtropical_poblacion_afect = tormenta_tropical['Población afectada '].replace('SD',0).sum()
#tormtropical_danos_econ = tormenta_tropical['Total de daños (millones de pesos)'].sum()

# %%
#tormtropical_poblacion_afect
#tormtropical_danos_econ

# %%
#poblacion_afect['Tormenta tropical']=tormtropical_poblacion_afect
#danos_economicos['Tormenta tropical']=tormtropical_danos_econ

# %%
impacto_social = pd.Series(poblacion_afect).sort_values(ascending=False)
impacto_economico = pd.Series(danos_economicos).sort_values(ascending=False)

# %%
fig=px.bar(impacto_social, color_discrete_sequence=['rgb(26, 118, 255)'], text_auto=True)
fig.update_layout(xaxis_title=" ", yaxis_title="Población afectada", showlegend=False)
fig.show()

# %%
fig=px.bar(impacto_economico, color_discrete_sequence=['rgb(26, 118, 255)'], text_auto=True)
fig.update_layout(xaxis_title=" ", yaxis_title="Daños en millones de pesos", showlegend=False)
fig.show()
